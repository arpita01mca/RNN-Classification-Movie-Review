# %%
from tensorflow.keras.preprocessing.text import one_hot
# Out:
# ---------------------------------------------------------------------------
# NotFoundError                             Traceback (most recent call last)
# Cell In[1], line 1
# ----> 1 from tensorflow.keras.preprocessing.text import one_hot
#
# File ~/miniforge3/envs/tf_m1_py39/lib/python3.9/site-packages/tensorflow/__init__.py:443
#     441 _plugin_dir = _os.path.join(_s, 'tensorflow-plugins')
#     442 if _os.path.exists(_plugin_dir):
# --> 443   _ll.load_library(_plugin_dir)
#     444   # Load Pluggable Device Library
#     445   _ll.load_pluggable_device_library(_plugin_dir)
#
# File ~/miniforge3/envs/tf_m1_py39/lib/python3.9/site-packages/tensorflow/python/framework/load_library.py:151, in load_library(library_location)
#     148     kernel_libraries = [library_location]
#     150   for lib in kernel_libraries:
# --> 151     py_tf.TF_LoadLibrary(lib)
#     153 else:
#     154   raise OSError(
#     155       errno.ENOENT,
#     156       'The file or folder to load kernel libraries from does not exist.',
#     157       library_location)
#
# NotFoundError: dlopen(/Users/pandeyraj/miniforge3/envs/tf_m1_py39/lib/python3.9/site-packages/tensorflow-plugins/libmetal_plugin.dylib, 6): Symbol not found: __ZNKSt3__115basic_stringbufIcNS_11char_traitsIcEENS_9allocatorIcEEE3strEv
#   Referenced from: /Users/pandeyraj/miniforge3/envs/tf_m1_py39/lib/python3.9/site-packages/tensorflow-plugins/libmetal_plugin.dylib (which was built for Mac OS X 12.3)
#   Expected in: /usr/lib/libc++.1.dylib

# %%
## sentences
sent=[
    'the glass of milk',
    'the glass of juice',
    'the cup of tea',
    'I am a good boy',
    'I am a good developer',
    'understand the meaning of words',
    'your videos are good',
]
